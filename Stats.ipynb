# %% [markdown]
# Load the dataset into a data analysis tool or programming environment (e.g., Python with pandas library).
#
# Identify numerical columns in the dataset.
#
# Calculate the mean, median, mode, and standard deviation for these columns.
#
# Provide a brief interpretation of these statistics.

# %%
import pandas as pd
import numpy as np

data=pd.read_csv('sales_data_with_discounts.csv')
data
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
data.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
data.tail()
# Out:
#            Date       Day  SKU City  Volume         BU  Brand      Model  \
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera  M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva  W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva   W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera  M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera    M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 445       1300               2600          15.475687       402.367873
# 446       2600              15600          17.057027      2660.896242
# 447       1600               3200          18.965550       606.897606
# 448       1900               5700          16.793014       957.201826
# 449       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# 445      2197.632127
# 446     12939.103758
# 447      2593.102394
# ...

# %%
data.isnull()
# Out:
#       Date    Day    SKU   City  Volume     BU  Brand  Model  Avg Price  \
# 0    False  False  False  False   False  False  False  False      False
# 1    False  False  False  False   False  False  False  False      False
# 2    False  False  False  False   False  False  False  False      False
# 3    False  False  False  False   False  False  False  False      False
# 4    False  False  False  False   False  False  False  False      False
# ..     ...    ...    ...    ...     ...    ...    ...    ...        ...
# 445  False  False  False  False   False  False  False  False      False
# 446  False  False  False  False   False  False  False  False      False
# 447  False  False  False  False   False  False  False  False      False
# 448  False  False  False  False   False  False  False  False      False
# 449  False  False  False  False   False  False  False  False      False
#
#      Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value
# ...

# %%
data.isnull().sum()
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %%
df=data.select_dtypes(include='number') #selecting numerical columns.
print(df)
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# ...

# %%
df.mean() #mean of numerical columns.
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
df.median() #median of numerical columns.
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
df.mode() #mode for numerical columns.
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0       3.0      400.0            24300.0           5.007822        69.177942
# 1       NaN      450.0                NaN           5.055218        73.025199
# 2       NaN      500.0                NaN           5.059801        93.649161
# 3       NaN     1300.0                NaN           5.072124        94.682735
# 4       NaN     8100.0                NaN           5.084108       102.705757
# ..      ...        ...                ...                ...              ...
# 445     NaN        NaN                NaN          19.940610     17900.983733
# 446     NaN        NaN                NaN          19.965340     21153.498820
# 447     NaN        NaN                NaN          19.976879     21496.675367
# 448     NaN        NaN                NaN          19.982257     25328.224204
# 449     NaN        NaN                NaN          19.992407     25738.022194
#
#      Net Sales Value
# ...

# %%
df.std() #standard deviation for numerical columns.
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
data.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %% [markdown]
# Histograms:
#
# Plot histograms for each numerical column.
#
# Analyze the distribution (e.g., skewness, presence of outliers) and provide inferences.

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

a=df.hist(bins=50,figsize=(20,15))

# %% [markdown]
# Box Plots:
#
# Create boxplots for numerical variables to identify outliers and the interquartile range.
#
# Discuss any findings, such as extreme values or unusual distributions.

# %%
df.boxplot( figsize=(10,8)) #outliers in this boxplot is shown by dots.
# Out:
# <Axes: >

# %%
data=data.drop('Date',axis=1) #dropping date column as it is not required.
print(data)
# Out:
#           Day  SKU City  Volume         BU  Brand       Model  Avg Price  \
# 0    Thursday  M01    C      15    Mobiles  RealU       RU-10      12100
# 1    Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus      10100
# 2    Thursday  M03    C       7    Mobiles   YouM       YM-99      16100
# 3    Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus      20100
# 4    Thursday  M05    C       3    Mobiles   YouM      YM-98        8100
# ..        ...  ...  ...     ...        ...    ...         ...        ...
# 445  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals       1300
# 446  Thursday  L07    C       6  Lifestyle   Viva   W-Western       2600
# 447  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge       1600
# 448  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals       1900
# 449  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes       3100
#
#      Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value
# ...

# %%
data=data.drop('City',axis=1)# dropping city column as it is not required.
print(data)
# Out:
#           Day  SKU  Volume         BU  Brand       Model  Avg Price  \
# 0    Thursday  M01      15    Mobiles  RealU       RU-10      12100
# 1    Thursday  M02      10    Mobiles  RealU   RU-9 Plus      10100
# 2    Thursday  M03       7    Mobiles   YouM       YM-99      16100
# 3    Thursday  M04       6    Mobiles   YouM  YM-99 Plus      20100
# 4    Thursday  M05       3    Mobiles   YouM      YM-98        8100
# ..        ...  ...     ...        ...    ...         ...        ...
# 445  Thursday  L06       2  Lifestyle  Jeera   M-Casuals       1300
# 446  Thursday  L07       6  Lifestyle   Viva   W-Western       2600
# 447  Thursday  L08       2  Lifestyle   Viva    W-Lounge       1600
# 448  Thursday  L09       3  Lifestyle  Jeera   M-Formals       1900
# 449  Thursday  L10       1  Lifestyle  Jeera     M-Shoes       3100
#
#      Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value
# ...

# %%
data_cat=data.select_dtypes(include='object')
print(data_cat)
# Out:
#           Day  SKU         BU  Brand       Model
# 0    Thursday  M01    Mobiles  RealU       RU-10
# 1    Thursday  M02    Mobiles  RealU   RU-9 Plus
# 2    Thursday  M03    Mobiles   YouM       YM-99
# 3    Thursday  M04    Mobiles   YouM  YM-99 Plus
# 4    Thursday  M05    Mobiles   YouM      YM-98
# ..        ...  ...        ...    ...         ...
# 445  Thursday  L06  Lifestyle  Jeera   M-Casuals
# 446  Thursday  L07  Lifestyle   Viva   W-Western
# 447  Thursday  L08  Lifestyle   Viva    W-Lounge
# 448  Thursday  L09  Lifestyle  Jeera   M-Formals
# 449  Thursday  L10  Lifestyle  Jeera     M-Shoes
#
# [450 rows x 5 columns]

# %% [markdown]
# Bar Chart Analysis for Categorical Column:
#
# Identify categorical columns in the dataset.
#
# Create bar charts to visualize the frequency or count of each category.
#
# Analyze the distribution of categories and provide insights.

# %%
for col in data_cat:
    plt.figure(figsize=(6,4))
    data[col].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title(f"Frequency of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()
