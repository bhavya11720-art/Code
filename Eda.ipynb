# %% [markdown]
# 1. Data Cleaning and Preparation:

# %%
import pandas as pd
import numpy as np

data=pd.read_csv('Cardiotocographic.csv')
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
data.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
data.tail()
# Out:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.0  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.0  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2121  25.000000   7.2   40.0       0.0  2.000000
# 2122  22.000000   7.1   66.0       1.0  2.000000
# 2123  20.000000   6.1   67.0       1.0  1.990464
# 2124  27.000000   7.0   66.0       1.0  2.000000
# 2125  35.857183   5.0   42.0       0.0  1.000000

# %%
data.shape
# Out:
# (2126, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
data.isnull()
# Out:
#          LB     AC     FM     UC     DL     DS     DP   ASTV   MSTV   ALTV  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2121  False  False  False  False  False  False  False  False  False  False
# 2122  False  False  False  False  False  False  False  False  False  False
# 2123  False  False  False  False  False  False  False  False  False  False
# 2124  False  False  False  False  False  False  False  False  False  False
# 2125  False  False  False  False  False  False  False  False  False  False
#
#        MLTV  Width  Tendency    NSP
# ...

# %%
data.isnull().sum() #There are null values in the dataset
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
data.fillna(0,inplace=True)

# %%
data.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
data.drop(columns=['DS','DP'],inplace=True)

# %%
data
# Out:
#               LB        AC        FM        UC        DL  ASTV  MSTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  73.0   0.5
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  17.0   2.1
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  16.0   2.1
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  16.0   2.4
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  16.0   2.4
# ...          ...       ...       ...       ...       ...   ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  79.0   0.2
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  78.0   0.4
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  79.0   0.4
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  78.0   0.4
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 0     43.000000   2.4   64.0  0.999926  2.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2126 non-null   float64
#  1   AC        2126 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   ASTV      2126 non-null   float64
#  6   MSTV      2126 non-null   float64
#  7   ALTV      2126 non-null   float64
#  8   MLTV      2126 non-null   float64
#  9   Width     2126 non-null   float64
#  10  Tendency  2126 non-null   float64
#  11  NSP       2126 non-null   float64
# dtypes: float64(12)
# memory usage: 199.4 KB

# %% [markdown]
# 2. Statistical Summary:

# %%
data.describe() # Get summary statistics for numerical columns
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    132.026470     0.003189     0.009894     0.004391     0.001895
# std      17.312967     0.004381     0.067540     0.003340     0.003343
# min       0.000000    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001572     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#               ASTV         MSTV         ALTV         MLTV        Width  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean     46.995984     1.364378    10.285964     8.203052    69.733581
# std      18.813973     1.173632    21.205041     7.777652    43.283505
# ...

# %%
#Here, count is same for all columns, indicating no missing values.
#others will provide insights(mean,std,min,max)

# %% [markdown]
# 3. Data Visualization:

# %% [markdown]
# Create histograms or boxplots to visualize the distributions of various
# numerical variables.

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

a=data.hist(bins=50,figsize=(12,15))

# %%
b=data.boxplot(figsize=(10,8))

# %%
data['LB'].nunique()
# Out:
# 154

# %%
data['AC'].nunique()
# Out:
# 1067

# %%
data['FM'].nunique()
# Out:
# 776

# %%
data['UC'].nunique()
# Out:
# 1364

# %%
data['DL'].nunique()
# Out:
# 822

# %%
data['ASTV'].nunique()
# Out:
# 183

# %%
data['MSTV'].nunique()
# Out:
# 165

# %%
data['ALTV'].nunique()
# Out:
# 195

# %%
data['Width'].nunique()
# Out:
# 262

# %%
data['Tendency'].nunique()
# Out:
# 111

# %%
data['NSP'].nunique()
# Out:
# 112

# %% [markdown]
# Use bar charts or pie charts to display the frequency of categories for categorical variables.

# %%
#Here we cant plot the bar chart for all the values as dataset has the many different unique values(>20)
#That's the reason here we ploted top 10 values
for col in data:
    plt.figure(figsize=(6,4))
    data[col].value_counts().head(10).plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title(f"Frequency of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %% [markdown]
# Generate scatter plots or correlation heatmaps to explore relationships between pairs of variables.

# %%
plt.scatter(data['LB'],data['AC'])
plt.xlabel('LB')
plt.ylabel('AC')
plt.show()

# %%
plt.scatter(data['FM'],data['UC'])
plt.xlabel('FM')
plt.ylabel('UC')
plt.show()

# %%
plt.scatter(data['Tendency'],data['NSP'])
plt.xlabel('Tendency')
plt.ylabel('NSP')
plt.show()

# %%
plt.scatter(data['ASTV'],data['ALTV'])
plt.xlabel('ASTV')
plt.ylabel('ALTV')
plt.show()

# %%
plt.scatter(data['ALTV'],data['NSP'])
plt.xlabel('ALTV')
plt.ylabel('NSP')
plt.show()

# %%
plt.scatter(data['ASTV'],data['NSP'])
plt.xlabel('ASTV')
plt.ylabel('NSP')
plt.show()

# %%
plt.scatter(data['DL'],data['MSTV'])
plt.xlabel('DL')
plt.ylabel('MSTV')
plt.show()

# %%
df=data.corr(numeric_only=True)
df
# Out:
#                 LB        AC        FM        UC        DL      ASTV  \
# LB        1.000000 -0.017110  0.019944 -0.114671 -0.089031  0.157044
# AC       -0.017110  1.000000  0.010100  0.071282 -0.093590 -0.230207
# FM        0.019944  0.010100  1.000000 -0.053226  0.009718 -0.032691
# UC       -0.114671  0.071282 -0.053226  1.000000  0.190128 -0.181161
# DL       -0.089031 -0.093590  0.009718  0.190128  1.000000 -0.069361
# ASTV      0.157044 -0.230207 -0.032691 -0.181161 -0.069361  1.000000
# MSTV     -0.131758  0.132085  0.017055  0.189406  0.410102 -0.293882
# ALTV      0.160667 -0.268194 -0.011936 -0.227304 -0.186967  0.357497
# MLTV      0.078050 -0.100780 -0.005126 -0.050046 -0.165256 -0.218452
# Width     0.046917  0.236053  0.097581  0.104280  0.401843 -0.204163
# Tendency  0.190314  0.033359 -0.017819 -0.066832 -0.023914 -0.010855
# NSP       0.233980 -0.299041  0.074608 -0.183183  0.023014  0.413137
#
#               MSTV      ALTV      MLTV     Width  Tendency       NSP
# ...

# %%
import seaborn as sns

sns.heatmap(data.corr(numeric_only=True))
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Employ advanced visualization techniques like pair plots, or violin plots for deeper insights.

# %%
plt.violinplot(data['NSP'])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x2604b0028c0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2604b0019c0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2604b0033a0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2604b0039a0>}

# %%
plt.violinplot(data['ASTV'])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x26049138730>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x26049109390>,
#  'cmins': <matplotlib.collections.LineCollection at 0x26049109360>,
#  'cbars': <matplotlib.collections.LineCollection at 0x260491391e0>}

# %%
plt.violinplot(data['ALTV'])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x260490f20b0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x260490f2740>,
#  'cmins': <matplotlib.collections.LineCollection at 0x260490f2cb0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x260490f32b0>}

# %%
plt.violinplot(data['Tendency'])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x260490893f0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x26049088610>,
#  'cmins': <matplotlib.collections.LineCollection at 0x26049089e70>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2604908a470>}

# %% [markdown]
#  Conclusion:
#  The analysis reveals that certain variables such as ASTV, ALTV, and NSP are strongly interrelated and likely important for understanding the dataset’s behavior.
